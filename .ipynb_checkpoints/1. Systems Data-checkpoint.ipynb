# %% [markdown]
# ## Here, our goal is to create a CSV file containing information about all the multiple/binary star systems that host known exoplanets.
#
# First, we have already downloaded a CSV file from NASA exoplanet archive called "nasa_exoplanet_data_where_no_of_hoststar_greater_than_1.csv" and saved it inside "source_data" folder. We downloaded it manually using their website and using the criteria "sy_snum != 0". This CSV file contains all the columns you will find here: https://exoplanetarchive.ipac.caltech.edu/docs/API_PS_columns.html
#
# Let's start with importing pandas

# %%
import pandas as pd

# %% [markdown]
# Now, we will read the CSV file and save it as a pandas DataFrame.

# %%
df = pd.read_csv("source_data/nasa_exoplanet_data_where_no_of_hoststar_greater_than_1.csv")

# %% [markdown]
# Let's see how many data do we have?

# %%
df.shape
# Out:
# (2332, 286)

# %% [markdown]
# So, we have 2332 rows and 286 columns. We will not need all the columns and also the rows are not unique (because our CSV file is from NASA Planetary Systems Data, **NOT** from NASA Planetary System *Composite* Data). Now let's extract the names of the systems from this data.

# %%
system_names = [row.hostname for (index, row) in df.iterrows()]

# %% [markdown]
# Let's inspect our list:

# %%
print("Number of elements: ", len(system_names))
for i in system_names:
    print(i)
# Out:
# Number of elements:  2332
# 11 Com
# 11 Com
# 16 Cyg B
# 16 Cyg B
# 16 Cyg B
# 16 Cyg B
# 16 Cyg B
# 16 Cyg B
# 18 Del
# 18 Del
# 2MASS J01033563-5515561 A
# 2MASS J19383260+4603591
# 2MASS J19383260+4603591
# 30 Ari B
# 30 Ari B
# 30 Ari B
# 42 Dra
# 51 Eri
# 51 Eri
# 51 Eri
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 55 Cnc
# 75 Cet
# 91 Aqr
# CoRoT-2
# CoRoT-2
# CoRoT-2
# CoRoT-2
# CoRoT-2
# CoRoT-2
# CoRoT-2
# CoRoT-2
# CoRoT-2
# CoRoT-9
# CoRoT-9
# CoRoT-9
# CoRoT-9
# DE CVn
# DMPP-3 A
# DMPP-3 A
# DP Leo
# DP Leo
# DS Tuc A
# DS Tuc A
# DS Tuc A
# EPIC 246851721
# EPIC 246851721
# GJ 15 A
# GJ 15 A
# GJ 15 A
# GJ 15 A
# GJ 229
# GJ 229
# GJ 229
# GJ 3021
# GJ 338 B
# GJ 3473
# GJ 3473
# GJ 3473
# GJ 414 A
# GJ 414 A
# GJ 414 A
# GJ 414 A
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 667 C
# GJ 676 A
# GJ 676 A
# GJ 676 A
# GJ 676 A
# GJ 676 A
# GJ 676 A
# GJ 676 A
# GJ 676 A
# GJ 676 A
# GJ 720 A
# GJ 86
# GJ 86
# GJ 86
# Gl 49
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-1
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-14
# HAT-P-16
# HAT-P-16
# HAT-P-16
# HD 98736
# HD 99492
# HD 99492
# HD 99492
# HD 99492
# HD 99492
# HD 99492
# HIP 109600
# HIP 116454
# HIP 116454
# HIP 65 A
# HIP 65 A
# HIP 65 A
# HIP 70849
# HIP 75056 A
# HIP 79098 AB
# HIP 8541
# HIP 94235
# HIP 94235
# HR 5183
# HR 5183
# HR 858
# HR 858
# HR 858
# HR 858
# HR 858
# HR 858
# HU Aqr
# HU Aqr
# HW Vir
# K2-122
# K2-122
# K2-122
# K2-122
# K2-122
# K2-122
# K2-122
# K2-122
# K2-136
# K2-136
# K2-136
# K2-136
# K2-136
# K2-136
# K2-136
# K2-136
# K2-148
# K2-148
# K2-148
# K2-148
# K2-148
# K2-148
# K2-151
# K2-151
# K2-151
# K2-151
# K2-22
# K2-22
# K2-22
# K2-22
# K2-22
# K2-22
# K2-22
# K2-265
# K2-265
# K2-265
# K2-265
# K2-265
# K2-265
# K2-266
# K2-266
# K2-266
# K2-266
# K2-266
# K2-266
# K2-27
# K2-27
# K2-27
# K2-27
# K2-27
# K2-27
# K2-27
# K2-27
# K2-27
# K2-288 B
# K2-288 B
# K2-29
# K2-29
# K2-29
# K2-29
# K2-29
# K2-29
# K2-29
# K2-29
# K2-290
# K2-290
# K2-31
# K2-31
# K2-31
# K2-31
# K2-31
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# K2-32
# KELT-15
# KELT-15
# KELT-15
# KELT-15
# KELT-16
# KELT-16
# KELT-16
# KELT-18
# KELT-18
# KELT-18
# KELT-18
# KELT-19 A
# KELT-19 A
# KELT-2 A
# KELT-2 A
# KELT-2 A
# KELT-2 A
# KELT-23 A
# KELT-23 A
# KELT-23 A
# KELT-3
# KELT-3
# KELT-3
# KELT-3
# KELT-3
# KELT-3
# KELT-4 A
# KELT-4 A
# KELT-9
# KELT-9
# KELT-9
# KIC 5095269
# KIC 5951458
# KMT-2021-BLG-0322L
# KMT-2021-BLG-0322L
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-1257
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-13
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# KOI-94
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1008
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-1027
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-104
# Kepler-1063
# Kepler-1063
# Kepler-1063
# Kepler-1063
# Kepler-1063
# Kepler-1063
# Kepler-1063
# Kepler-1063
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-108
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1086
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1130
# Kepler-1150
# Kepler-1150
# Kepler-1150
# Kepler-1150
# Kepler-1150
# Kepler-1150
# Kepler-1150
# Kepler-1150
# Kepler-1150
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-130
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-1319
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-132
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-1341
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-136
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-14
# Kepler-1480
# Kepler-1480
# Kepler-1480
# Kepler-1480
# Kepler-1480
# Kepler-1480
# Kepler-1480
# Kepler-1480
# Kepler-1480
# Kepler-1540
# Kepler-1540
# Kepler-1540
# Kepler-1540
# Kepler-1540
# Kepler-1540
# Kepler-1540
# Kepler-1540
# Kepler-16
# Kepler-1647
# Kepler-1651
# Kepler-1651
# Kepler-1651
# Kepler-1651
# Kepler-1651
# Kepler-1651
# Kepler-1651
# Kepler-1661
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-167
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-197
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-20
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-21
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-25
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-296
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-333
# Kepler-34
# Kepler-35
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-353
# Kepler-38
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-390
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-410 A
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-411
# Kepler-413
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-432
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# Kepler-444
# 2MASS J19383260+4603591
# 2MASS J19383260+4603591
# Kepler-453
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-454
# Kepler-47
# Kepler-47
# Kepler-47
# Kepler-47
# Kepler-47
# Kepler-477
# Kepler-477
# Kepler-477
# Kepler-477
# Kepler-477
# Kepler-477
# Kepler-477
# Kepler-477
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-504
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-514
# Kepler-515
# Kepler-515
# Kepler-515
# Kepler-515
# Kepler-515
# Kepler-515
# Kepler-515
# Kepler-515
# Kepler-515
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-517
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-519
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-530
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-538
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-560
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-636
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-68
# Kepler-693
# Kepler-693
# Kepler-693
# Kepler-693
# Kepler-693
# Kepler-693
# Kepler-693
# Kepler-693
# Kepler-693
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-743
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-755
# Kepler-779
# Kepler-779
# Kepler-779
# Kepler-779
# Kepler-779
# Kepler-779
# Kepler-779
# Kepler-779
# Kepler-779
# Kepler-78
# Kepler-78
# Kepler-78
# Kepler-78
# Kepler-78
# Kepler-78
# Kepler-78
# Kepler-795
# Kepler-795
# Kepler-795
# Kepler-795
# Kepler-795
# Kepler-795
# Kepler-795
# Kepler-795
# Kepler-795
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-83
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-908
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-951
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-970
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# Kepler-99
# LHS 1678
# LHS 1678
# LHS 1678
# LHS 1678
# LTT 1445 A
# LTT 1445 A
# LTT 1445 A
# LTT 1445 A
# LTT 3780
# LTT 3780
# LTT 3780
# LTT 3780
# LTT 3780
# LTT 3780
# MASCARA-4
# MASCARA-4
# MXB 1658-298
# NGTS-14 A
# NGTS-3 A
# NGTS-3 A
# NN Ser
# NN Ser
# NN Ser
# NN Ser
# NSVS 14256825
# NY Vir
# NY Vir
# NY Vir
# NY Vir
# OGLE-2007-BLG-349L A
# OGLE-2008-BLG-092L
# OGLE-2013-BLG-0341L B
# OGLE-2013-BLG-0341L B
# OGLE-2013-BLG-0341L B
# OGLE-2013-BLG-0341L B
# OGLE-2016-BLG-0613L AB
# OGLE-2016-BLG-0613L AB
# OGLE-2016-BLG-0613L AB
# OGLE-2016-BLG-0613L AB
# OGLE-2016-BLG-0613L AB
# OGLE-2016-BLG-0613L AB
# OGLE-2018-BLG-1700L
# OGLE-2018-BLG-1700L
# OGLE-2019-BLG-0304L
# PH1
# PSR B1620-26
# Pr0211
# Pr0211
# Pr0211
# Proxima Cen
# Proxima Cen
# Qatar-6
# Qatar-6
# ROXs 12
# ROXs 12
# ROXs 42 B
# ROXs 42 B
# ROXs 42 B
# RR Cae
# Ross 458
# Ross 458
# SR 12 AB
# TIC 172900988 Aa
# TIC 172900988 Aa
# TIC 172900988 Aa
# TIC 172900988 Aa
# TIC 172900988 Aa
# TIC 172900988 Aa
# TOI-1201
# TOI-1201
# TOI-1259 A
# TOI-1259 A
# TOI-1333
# TOI-1333
# TOI-1338
# TOI-1338
# TOI-1634
# TOI-1634
# TOI-1634
# TOI-3714
# TOI-3714
# TOI-421
# TOI-421
# TOI-421
# TOI-421
# TOI-451
# TOI-451
# TOI-451
# TOI-451
# TOI-451
# TOI-451
# TOI-942
# TOI-942
# TOI-942
# TOI-942
# TOI-942
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-1
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-2
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# TrES-4
# UZ For
# UZ For
# VHS J125601.92-125723.9
# VHS J125601.92-125723.9
# VHS J125601.92-125723.9
# WASP-1
# WASP-1
# WASP-1
# WASP-1
# WASP-1
# WASP-1
# WASP-1
# WASP-1
# WASP-1
# WASP-1
# WASP-100
# WASP-100
# WASP-85 A
# WASP-85 A
# WASP-85 A
# WASP-85 A
# WASP-85 A
# WASP-85 A
# WASP-87
# WASP-87
# WASP-94 A
# WASP-94 A
# WASP-94 A
# WASP-94 A
# WASP-94 B
# WASP-98
# WASP-98
# WASP-98
# WASP-98
# WASP-98
# WD 1856+534
# WD 1856+534
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 N
# XO-2 S
# XO-2 S
# XO-2 S
# alf Tau
# b Cen A
# bet Cnc
# eps Ind A
# gam 1 Leo
# gam Cep
# gam Cep
# gam Cep
# ome Ser
# omi UMa
# psi 1 Dra B
# tau Boo
# tau Boo
# tau Boo
# tau Boo
# tau Boo
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And
# ups And

# %% [markdown]
# As you can see that there are two problems: (1) There are duplicate values, (2) some system names have A/B/C/S/N/Aa/Ab etc. at the end. However, these are to denote stars. In this catalogue, we will use these to denote star name, not system name. For example, if our planet is **OGLE-2016-BLG-0613L AB b**, then in that planetary sysem, star names are **OGLE-2016-BLG-0613L A** and **OGLE-2016-BLG-0613L B**. System name is **OGLE-2016-BLG-0613L**. So, let's clean this list first.
#
# Please, run the below code block at least 3 times! I couldn't find a better way. It removes one character from the end including whitespace. So if you just run it once, **OGLE-2016-BLG-0613L AB** will be converted to **OGLE-2016-BLG-0613L A**. If you run it twice, it will be **OGLE-2016-BLG-0613L' '** (with a whitespace at the end). That's why (for the following block of code only) run at least three times or maybe four times! And if you have a better way, please implement.

# %%
for k in range(len(system_names)):
    i = system_names[k]
    if i[-1] in ['A', 'B', 'S', 'N', 'C', ' '] or i[-2:] == 'Aa' or i[-2:] == 'Ab':
        system_names[k] = system_names[k][:-1]

# %% [markdown]
# Now, we will only collect the unique system names from the list and saved all unique names to the same list. We also sorted the data for better inspection.

# %%
system_names = sorted(list(set(system_names)))

# %% [markdown]
# Now, we should have only the unique names. Let's see how many multiple/binary systems there are that hosts exoplanets!

# %%
print("There are a total of ", len(system_names), " systems that contains more than 1 star and host exoplanets.")
for i in system_names:
    print(i)
# Out:
# There are a total of  341  systems that contains more than 1 star and host exoplanets.
# 11 Com
# 16 Cyg
# 18 Del
# 2MASS J01033563-5515561
# 2MASS J19383260+4603591
# 30 Ari
# 42 Dra
# 51 Eri
# 55 Cnc
# 75 Cet
# 91 Aqr
# CoRoT-2
# CoRoT-9
# DE CVn
# DMPP-3
# DP Leo
# DS Tuc
# EPIC 246851721
# GJ 15
# GJ 229
# GJ 3021
# GJ 338
# GJ 3473
# GJ 414
# GJ 667
# GJ 676
# GJ 720
# GJ 86
# Gl 49
# HAT-P-1
# HAT-P-14
# HAT-P-16
# HAT-P-22
# HAT-P-24
# HAT-P-27
# HAT-P-29
# HAT-P-3
# HAT-P-30
# HAT-P-32
# HAT-P-33
# HAT-P-35
# HAT-P-39
# HAT-P-4
# HAT-P-41
# HAT-P-57
# HAT-P-67
# OGLE-2013-BLG-0341L
# OGLE-2016-BLG-0613L
# OGLE-2018-BLG-1700L
# OGLE-2019-BLG-0304L
# PH1
# PSR B1620-26
# Pr0211
# Proxima Cen
# Qatar-6
# ROXs 12
# ROXs 42
# RR Cae
# Ross 458
# SR 12
# TIC 172900988
# TOI-1201
# TOI-1259
# TOI-1333
# TOI-1338
# TOI-1634
# TOI-3714
# TOI-421
# TOI-451
# TOI-942
# TrES-1
# TrES-2
# TrES-4
# UZ For
# VHS J125601.92-125723.9
# WASP-1
# WASP-100
# WASP-104
# WASP-11
# WASP-114
# WASP-12
# WASP-123
# WASP-127
# WASP-129
# WASP-139
# WASP-14
# WASP-140
# WASP-145
# WASP-160
# WASP-168
# WASP-173
# WASP-18
# WASP-180
# WASP-2
# WASP-20
# WASP-24
# WASP-26
# WASP-3
# WASP-33
# WASP-36
# WASP-45
# WASP-49
# WASP-54
# WASP-55
# WASP-56
# WASP-58
# WASP-64
# WASP-68
# WASP-70
# WASP-75
# WASP-76
# WASP-77
# WASP-8
# WASP-85
# WASP-87
# WASP-94
# WASP-98
# WD 1856+534
# XO-2
# alf Tau
# b Cen
# bet Cnc
# eps Ind
# gam 1 Leo
# gam Cep
# ome Ser
# omi UMa
# psi 1 Dra
# tau Boo
# ups And

# %% [markdown]
# Now, let's convert this list to a DataFrame and then inspect. This will be our primary DataFrame.

# %%
system_df = pd.DataFrame(system_names, columns=['System'])
system_df.head()
# Out:
#                     System
# 0                   11 Com
# 1                   16 Cyg
# 2                   18 Del
# 3  2MASS J01033563-5515561
# 4  2MASS J19383260+4603591

# %% [markdown]
# Now, we will add Spectral_Type of these systems such as sdB/O/G2 etc. This is little confusing since systems do not have spectral type, stars have. So, a system spectral type should ideally be something like sdB+dM or G8+IIIFe-1 etc. We will query these from SIMBAD. However, the problem is that in SIMBAD, they store the data for stars, not always for systmes. For example, for 16 Cyg, we don't have SIMBAD data. But for 16 Cyg A or 16 Cyg B, we have their data in SIMBAD. Their spectral types and RA,DEC are also different.
#
# For spectral type, we can query the spectral type of the stars seperately and then join them using a '+' sign. But how can we record the RA and DEC data of a system!? Should RA and DEC column be for stars instead of systems then!? I don't understand this part.

# %% [markdown]
# But since for most of the system, SIMBAD has the data, I am going to carry on. Where they have seperate data for each star in the system (but not for the system as a whole), we can input the data later manually (there are not that many systems, around 10-15. So, it should be not be much difficult).

# %% [markdown]
# To do that, first let's connect to SIMBAD via astroquery. The spectral type data column is not added by default. So we have to add it seperately.

# %%
from astroquery.simbad import Simbad
customSimbad = Simbad()
customSimbad.add_votable_fields('sptype')

# %% [markdown]
# Let's define a new column in our DataFrame called 'Type' to save the spectral types there and another column to save the reference of the spectral type.

# %%
system_df['Type'] = ""
system_df['Type_ref'] = ""

# %% [markdown]
# Now, we will query each object from our DataFrame rows, receive their spectral type, and lastly save their sp_type. But note that since not all of the system are available in SIMBAD, they will give us warning and will return null result for that object. That's why to avoid any error, we will write the data into our DataFrame only when the result is not NoneType. And to suppress the warnings (there will be a lot of warning, 4-5 lines for each missing object), we will do the following. You can comment the following code and see the warning in case you want to debug or understand the warnings.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for i, data in system_df.iterrows():
    result = customSimbad.query_object(data.System)
    if result:
        system_df['Type'][i] = result['SP_TYPE'][0]
        system_df['Type_ref'][i] = result['SP_BIBCODE'][0]

# %% [markdown]
# Let's look at our dataframe now.

# %%
system_df.head()
# Out:
#                     System        Type             Type_ref
# 0                   11 Com  G8+IIIFe-1  1989ApJS...71..245K
# 1                   16 Cyg
# 2                   18 Del       G6III  1957ArA.....2...55O
# 3  2MASS J01033563-5515561        M5.0  2014AJ....147..146K
# 4  2MASS J19383260+4603591      sdB+dM  2010MNRAS.408L..51O

# %% [markdown]
# It looks good! Now, similarly, we will query Gaia_ID from the SIMBAD data. Using astroquery, we can query all the IDs of an object (Gaia, HIP, 2M etc.). We will get all the identifiers and then choose the Gaia DR3 ID only. Note that for a few systems, they have Gaia DR2 ID but not Gaia DR3 ID. I don't know what to do with them. Since they are only a few, we can add them later manually.

# %%
system_df['Gaia_ID'] = ""

# %%
for i, data in system_df.iterrows():
    id_result = Simbad.query_objectids(data.System)
    if id_result:
        for x in id_result:
            if 'gaia dr3' in x['ID'].lower():
                system_df['Gaia_ID'][i] = x['ID']

# %% [markdown]
# Now, let's look at our dataframe.

# %%
system_df.head()
# Out:
#                     System        Type             Type_ref  \
# 0                   11 Com  G8+IIIFe-1  1989ApJS...71..245K
# 1                   16 Cyg
# 2                   18 Del       G6III  1957ArA.....2...55O
# 3  2MASS J01033563-5515561        M5.0  2014AJ....147..146K
# 4  2MASS J19383260+4603591      sdB+dM  2010MNRAS.408L..51O
#
#                         Gaia_ID
# 0  Gaia DR3 3946945413106333696
# 1
# 2  Gaia DR3 1756741374681702784
# 3
# 4  Gaia DR3 2080063931448749824

# %% [markdown]
# It's unfortunate that for top 5 rows, we have only 3 Gaia DR3 ID. However, don't worry cause for the rest of the data, we mostly have this ID. (around 10% ID is missing). After adding the DR2 ID, we will have only a few data missing.

# %% [markdown]
# We are almost finished! Since we have the Gaia ID. Now we can get all other columns data from Gaia. We don't need SIMBAD anymore. Let's connect to Gaia DR3. We will retrieve rest of the data from Gaia DR3

# %%
from astroquery.gaia import Gaia
Gaia.MAIN_GAIA_TABLE = "gaiadr3.gaia_source"
gdr3 = Gaia.load_table('gaiadr3.gaia_source')
# Out:
# Retrieving table 'gaiadr3.gaia_source'

# %% [markdown]
# First, let us define all the columns we need. The column titles are self-explanatory

# %%
system_df['ra'] = ''
system_df['ra_error'] = ''
system_df['dec'] = ''
system_df['dec_error'] = ''
system_df['parallax'] = ''
system_df['parallax_error'] = ''
system_df['distance_gspphot'] = ''
system_df['distance_gspphot_upper'] = ''
system_df['distance_gspphot_lower'] = ''
system_df['pmra'] = ''
system_df['pmra_error'] = ''
system_df['pmdec'] = ''
system_df['pmdec_error'] = ''
system_df['pm'] = ''
system_df['radial_velocity'] = ''
system_df['radial_velocity_error'] = ''

system_df.head()
# Out:
#                     System        Type             Type_ref  \
# 0                   11 Com  G8+IIIFe-1  1989ApJS...71..245K
# 1                   16 Cyg
# 2                   18 Del       G6III  1957ArA.....2...55O
# 3  2MASS J01033563-5515561        M5.0  2014AJ....147..146K
# 4  2MASS J19383260+4603591      sdB+dM  2010MNRAS.408L..51O
#
#                         Gaia_ID ra ra_error dec dec_error parallax  \
# 0  Gaia DR3 3946945413106333696
# 1
# 2  Gaia DR3 1756741374681702784
# 3
# 4  Gaia DR3 2080063931448749824
#
#   parallax_error distance_gspphot distance_gspphot_upper  \
# 0
# 1
# 2
# 3
# 4
#
#   distance_gspphot_lower pmra pmra_error pmdec pmdec_error pm radial_velocity  \
# 0
# 1
# 2
# 3
# 4
#
#   radial_velocity_error
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Now, we are going to create a string of all Gaia_IDs for our system_df. It will help in the ADQL query.

# %%
ID_string = "','".join(list(system_df.Gaia_ID))
ID_string = ID_string.replace(",'',", ",")

# %%
query = """SELECT designation, ra, ra_error, dec, dec_error, parallax, parallax_error, distance_gspphot, 
distance_gspphot_upper, distance_gspphot_lower, pmra, pmra_error, pmdec, pmdec_error, pm, radial_velocity, 
radial_velocity_error FROM gaiadr3.gaia_source AS gdr3 WHERE DESIGNATION IN ('""" +  ID_string + """')"""

# %%
job = Gaia.launch_job(query)

# %%
gaia_tb = job.get_results()
gaia_df = gaia_tb.to_pandas()
gaia_df.head()
# Out:
#                     DESIGNATION          ra  ra_error        dec  dec_error  \
# 0  Gaia DR3 1019003226022657920  140.656962  0.012741  50.603778   0.011434
# 1   Gaia DR3 102082477749475200   39.241295  0.028020  24.648009   0.026262
# 2  Gaia DR3 1041808368494264576  127.564911  0.086310  60.717690   0.088616
# 3  Gaia DR3 1153682508388170112  227.215495  0.017102   2.343285   0.017424
# 4  Gaia DR3 1159336403336463872  222.767318  0.014751   5.947362   0.013854
#
#     parallax  parallax_error  distance_gspphot  distance_gspphot_upper  \
# 0  15.143903        0.016966         65.872704               65.959801
# 1  22.510725        0.031530         44.360100               44.422199
# 2  17.933453        0.145647         59.303398               59.437698
# 3   3.033025        0.020761        325.248688              329.288696
# 4   4.952760        0.016896        197.660400              198.575607
#
#    distance_gspphot_lower        pmra  pmra_error       pmdec  pmdec_error  \
# 0               65.789299   56.022466    0.015300   10.330508     0.014520
# 1               44.292400  140.950523    0.033430  -10.535567     0.028294
# 2               59.170898 -133.643561    0.090977 -107.664451     0.112253
# 3              322.979004  -16.741140    0.020410   -8.556390     0.022494
# 4              195.938797  -28.609940    0.019363   -2.774496     0.019092
#
#            pm  radial_velocity  radial_velocity_error
# 0   56.966972         3.786962               0.162834
# 1  141.343719        12.378623               0.307336
# 2  171.616531              NaN                    NaN
# 3   18.800999       -17.456457               0.575703
# 4   28.744156       -16.741198               0.558079

# %% [markdown]
# As you can see, we have received all the parameters we are interested in for systems in our system_df dataframe. However, I cannot figure out how to merge these two DataFrame. So, I will go for a **VERY VERY** inefficient way which is querying each object separately and the store one by one. It will take around 5 minutes to run the following code! Please change these code if you find a better alternative. There must be an easier way using pandas but at this moment, I cannot figure it out.

# %%
for i, data in system_df.iterrows():
    query = "SELECT ra, ra_error, dec, dec_error, parallax, parallax_error, distance_gspphot, distance_gspphot_upper, distance_gspphot_lower, pmra, pmra_error, pmdec, pmdec_error, pm, radial_velocity, radial_velocity_error FROM gaiadr3.gaia_source AS gdr3 WHERE gdr3.designation = '" + data.Gaia_ID + "'"
    job = Gaia.launch_job(query)
    result = job.get_results()
    if result:
        system_df['ra'][i] = result[0]['ra']
        system_df['ra_error'][i] = result[0]['ra_error']
        system_df['dec'][i] = result[0]['dec']
        system_df['dec_error'][i] = result[0]['dec_error']
        system_df['parallax'][i] = result[0]['parallax']
        system_df['parallax_error'][i] = result[0]['parallax_error']
        system_df['distance_gspphot'][i] = result[0]['distance_gspphot']
        system_df['distance_gspphot_upper'][i] = result[0]['distance_gspphot_upper']
        system_df['distance_gspphot_lower'][i] = result[0]['distance_gspphot_lower']
        system_df['pmra'][i] = result[0]['pmra']
        system_df['pmra_error'][i] = result[0]['pmra_error']
        system_df['pmdec'][i] = result[0]['pmdec']
        system_df['pmdec_error'][i] = result[0]['pmdec_error']
        system_df['pm'][i] = result[0]['pm']
        system_df['radial_velocity'][i] = result[0]['radial_velocity']
        system_df['radial_velocity_error'][i] = result[0]['radial_velocity_error']

# %% [markdown]
# The above code block query each object one by one then store the parameters in the system_df one-by-one. This is one of the most inefficient way of working. Ideally, one should be able to merge/join the system_df and gaia_df tables. This is **NOT** that much computationally inefficient. But it is inefficient, because there is a limit of how many times can you request data from Gaia using astroquery and instead of a single query this is separate query for each object! That's why it is slow.
#
# Anyway, let's see what we have achieved so far.

# %%
system_df.head()
# Out:
#                     System        Type             Type_ref  \
# 0                   11 Com  G8+IIIFe-1  1989ApJS...71..245K
# 1                   16 Cyg
# 2                   18 Del       G6III  1957ArA.....2...55O
# 3  2MASS J01033563-5515561        M5.0  2014AJ....147..146K
# 4  2MASS J19383260+4603591      sdB+dM  2010MNRAS.408L..51O
#
#                         Gaia_ID          ra  ra_error        dec dec_error  \
# 0  Gaia DR3 3946945413106333696  185.178763   0.10266  17.793264   0.10379
# 1
# 2  Gaia DR3 1756741374681702784   314.60783  0.057461  10.839133  0.040246
# 3
# 4  Gaia DR3 2080063931448749824  294.635918  0.027756  46.066407  0.031607
#
#     parallax parallax_error distance_gspphot distance_gspphot_upper  \
# 0   10.16768       0.136477       100.691399             105.460098
# 1
# 2  13.302135       0.065184               --                     --
# 3
# 4   2.440961       0.031625               --                     --
#
#   distance_gspphot_lower        pmra pmra_error      pmdec pmdec_error  \
# 0              91.518402 -109.425802    0.14367  88.929919     0.10673
# 1
# 2                     --  -49.920763   0.070463 -34.508749    0.043686
# 3
# 4                     --    5.225044   0.037355  -4.404689    0.042169
#
#            pm radial_velocity radial_velocity_error
# 0  141.005447       43.251984              0.139289
# 1
# 2   60.687202        4.171299               0.11649
# 3
# 4    6.833913              --                    --

# %% [markdown]
# This looks good. We have almost all the data columns that we need. We don't have angle of periapsis, age of the star, semi-major axis etc. that will be collected later from the literature and can be added to this dataframe.

# %% [markdown]
# Now, as a last step, we will save this dataframe to a csv file named systems.csv

# %%
system_df.to_csv("systems.csv", sep=',', encoding='utf-8', index=False)

# %% [markdown]
# Now, since we have the system data, we can go forward and do the same thing for stars and planets based on the system data. One thing to take note is that for system data, our data is coming from Gaia DR3 except the spectral type which is coming from SIMBAD and the corresponding bibcode is also saved into our DataFrame. But for planets data or stars data, parameters can come from a wide variety of sources and literatures. So, we better be careful.

# %% [markdown]
# ## The END
