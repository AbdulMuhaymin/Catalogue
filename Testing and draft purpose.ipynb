# %%
import pandas as pd

# %%
df = pd.read_csv("source_data/nasa_exoplanet_data_where_no_of_hoststar_greater_than_1.csv")

# %%
df.head()
# Out:
#                         pl_name                   hostname pl_letter  \
# 0                      11 Com b                     11 Com         b
# 1                    16 Cyg B b                   16 Cyg B         b
# 2                      18 Del b                     18 Del         b
# 3  2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A         b
# 4     2MASS J19383260+4603591 b    2MASS J19383260+4603591         b
#
#      hd_name    hip_name         tic_id                       gaia_id  \
# 0  HD 107383   HIP 60202   TIC 72437047  Gaia DR2 3946945413106333696
# 1  HD 186427   HIP 96901   TIC 27533327  Gaia DR2 2135550755683407232
# 2  HD 199665  HIP 103527  TIC 354489950  Gaia DR2 1756741374681702784
# 3        NaN         NaN  TIC 206502540                           NaN
# 4        NaN         NaN  TIC 271164763  Gaia DR2 2080063931448749824
#
#    sy_snum  sy_pnum  sy_mnum  ...  sy_kepmag sy_kepmagerr1  sy_kepmagerr2  \
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# pl_name
# hostname
# pl_letter
# hd_name
# hip_name
# tic_id
# gaia_id
# sy_snum
# sy_pnum
# sy_mnum
# cb_flag
# discoverymethod
# disc_year
# disc_refname
# disc_pubdate
# disc_locale
# disc_facility
# disc_telescope
# disc_instrument
# rv_flag
# pul_flag
# ptv_flag
# tran_flag
# ast_flag
# obm_flag
# micro_flag
# etv_flag
# ima_flag
# dkin_flag
# pl_controv_flag
# pl_orbper
# pl_orbpererr1
# pl_orbpererr2
# pl_orbperlim
# pl_orbper_reflink
# pl_orbsmax
# pl_orbsmaxerr1
# pl_orbsmaxerr2
# pl_orbsmaxlim
# pl_orbsmax_reflink
# pl_rade
# pl_radeerr1
# pl_radeerr2
# pl_radelim
# pl_rade_reflink
# pl_radj
# pl_radjerr1
# pl_radjerr2
# pl_radjlim
# pl_radj_reflink
# pl_bmasse
# pl_bmasseerr1
# pl_bmasseerr2
# pl_bmasselim
# pl_bmasse_reflink
# pl_bmassj
# pl_bmassjerr1
# pl_bmassjerr2
# pl_bmassjlim
# pl_bmassj_reflink
# pl_bmassprov
# pl_dens
# pl_denserr1
# pl_denserr2
# pl_denslim
# pl_dens_reflink
# pl_orbeccen
# pl_orbeccenerr1
# pl_orbeccenerr2
# pl_orbeccenlim
# ...

# %%
cols = list(df.columns)

# %%
planet_df = (df[cols[0:2] + ['discoverymethod' , 'pl_orbper' , 'pl_orbpererr1' , 'pl_orbpererr2' , 'pl_bmassj' , 
                'pl_bmassjerr1' , 'pl_bmassjerr2' , 'pl_msinij' , 'pl_msinijerr1' , 'pl_msinijerr2' , 'pl_radj' , 
                'pl_radjerr1' , 'pl_radjerr2' , 'pl_orbsmax' , 'pl_orbsmaxerr1' , 'pl_orbsmaxerr2' , 'pl_orbeccen' , 
                'pl_orbeccenerr1' , 'pl_orbeccenerr2']])

# %%
planet_df.head()
# Out:
#       pl_name  hostname  discoverymethod  pl_orbper  pl_orbpererr1  \
# 0    11 Com b    11 Com  Radial Velocity     326.03           0.32
# 1    11 Com b    11 Com  Radial Velocity        NaN            NaN
# 2  16 Cyg B b  16 Cyg B  Radial Velocity     799.50           0.60
# 3  16 Cyg B b  16 Cyg B  Radial Velocity     798.50           1.00
# 4  16 Cyg B b  16 Cyg B  Radial Velocity     800.80          11.70
#
#    pl_orbpererr2  pl_bmassj  pl_bmassjerr1  pl_bmassjerr2  pl_msinij  ...  \
# 0          -0.32      19.40           1.50          -1.50      19.40  ...
# 1            NaN      17.10           1.70          -1.30      17.10  ...
# 2          -0.60       1.68           0.07          -0.07       1.68  ...
# 3          -1.00       1.78           0.08          -0.08       1.78  ...
# 4         -11.70       1.50            NaN            NaN       1.50  ...
#
#    pl_msinijerr2  pl_radj  pl_radjerr1  pl_radjerr2  pl_orbsmax  \
# ...

# %%
planet_df.to_csv("created_data/planets.csv", index=False)
